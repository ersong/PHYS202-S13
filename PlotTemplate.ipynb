# %% [markdown]
# $5.$ Create a new notebook
#
#
# le called PlotTemplates in your main repository directory
#
#
#
# (not in the Week3 directory).
#
#
#
#
#
#
#
# (a) Add a markdown cell at the top with the heading \Publication ready plot template"
#
#
#
# and the description, \Simple graphing template for matplotlib functions and data plots.".

# %% [markdown]
# Publication ready plot template
# ===============================
# Simple graphing template for matplotlib functions and data plots.

# %% [markdown]
# (b) Add another markdown cell beneath that one with a smaller heading "Line plots".

# %% [markdown]
# Line plots
# -----------

# %% [markdown]
# (c) Add one cell to create the data arrays for the following functions over the range {5 <
# y < 5}
#
# E = $cosh(y)$
#
# |p| = $sinh(y)$
#
# Use regular python #comment formatting to describe the steps in this cell.

# %%
import numpy as np #import numpy type arrays for use
import math #give access to math functions
step=.01#distance between each consecutive y
y=arange(-5.,5.+step,step)#y is every step from -5 to 5(y)
E=cosh(y) #define E
p=sinh(y) #supposed to be |p|, but p must be greater than or equal to 0 for this to be true.

# %% [markdown]
# (d) Add one more cell for all of the commands and customizations needed to make a
# publication-ready graph of the data from part (b). Remove the bounding box on the gure
# and center the horizontal and vertical axis lines (called spines) at (0, 0). Use generic labels
# for the lines and axes. Remember, this is just a template. Again, use regular python
# comment formatting to describe the steps in this cell. You'll need to get the current axis
# and manipulate the spines. Try these out:

# %%
ax = gca()
ax.spines['right'].set_color('none') #remove spines
ax.spines['top'].set_color('none')
ax.spines['left'].set_color('none')
ax.spines['bottom'].set_color('none')
plot(y,E,color="red",linewidth=2.5,label="$sinh(x)$") #plotting E with red line, width 2.5, and labeling the curve
plot(y,p,color="blue",linewidth=2.5,label="$cosh(x)$") #plotting p with blue line, width 2.5, and labeling the curve
xlabel("y", fontsize=15)# label horizontal axis
ylabel("E(y) and p(y)",fontsize=15) # label vertical axis
legend() #show legend
grid(True)
#xvals = np.arange(-pi, pi, pi/4) (For future reference)
#plt.axis([-pi-.5, pi+.5, -1.1, 1.1])
#legend(loc = 'lower left')

# %% [markdown]
# (e) Repeat step (b) using the heading "Subplots", and step (d), to create two side-by-side
# or top-and-bottom plots of your data from part (c) using the subplot() command. Be
# sure to include comments.

# %% [markdown]
# Subplots
# --------

# %%
subplot(1,1,0)#note python numberin
plot(y,E,color="red",linewidth=2.5,label="$sinh(x)$") #plotting E with red line, width 2.5, and labeling the curve
show()#show one
subplot(1,1,1)
plot(y,p,color="blue",linewidth=2.5,label="$cosh(x)$") #plotting p with blue line, width 2.5, and labeling the curve
show()#show other

# %% [markdown]
# (f) Go back and look at question 4. In that question, you made a nicely formatted scatter
# plot. Now add new cells to repeat parts (b) through (d) for this new category ("Scatter
# plots") of figure. You can just create some dummy (x,y) data with the random number
# generator like this:

# %%
import matplotlib
n = 200
X = random.normal(0,1,n)
Y = random.normal(0,1,n)
figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')#set size of graph
scatter(X,Y,color="red",label="X and Y point")
xlabel("X", fontsize=15)# label horizontal axis
ylabel("Y",fontsize=15) # label vertical axis
legend() #show legend
grid(True)
