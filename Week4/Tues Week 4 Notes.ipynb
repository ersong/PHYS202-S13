# %% [markdown]
# 3D Plotting and Functions
# =========================

# %% [markdown]
# Electric Dipole Equation
# --------------------------

# %% [markdown]
# $V(x,y)=\dfrac{kq}{\sqrt{x^2+(y-d)^2}}-\dfrac{kq}{\sqrt{x^2+(y+d)^2}}$

# %%
dx=.06
dy=.06
x=arange(-2.,2.,dx)
y=arange(-2.,2.,dy)
X,Y = meshgrid(x,y)
print X.ndim
print Y.shape
print X
print Y
# Out:
# 2
# (67L, 67L)
# [[-2.   -1.94 -1.88 ...,  1.84  1.9   1.96]
#  [-2.   -1.94 -1.88 ...,  1.84  1.9   1.96]
#  [-2.   -1.94 -1.88 ...,  1.84  1.9   1.96]
#  ...,
#  [-2.   -1.94 -1.88 ...,  1.84  1.9   1.96]
#  [-2.   -1.94 -1.88 ...,  1.84  1.9   1.96]
#  [-2.   -1.94 -1.88 ...,  1.84  1.9   1.96]]
# [[-2.   -2.   -2.   ..., -2.   -2.   -2.  ]
#  [-1.94 -1.94 -1.94 ..., -1.94 -1.94 -1.94]
#  [-1.88 -1.88 -1.88 ..., -1.88 -1.88 -1.88]
#  ...,
#  [ 1.84  1.84  1.84 ...,  1.84  1.84  1.84]
#  [ 1.9   1.9   1.9  ...,  1.9   1.9   1.9 ]
#  [ 1.96  1.96  1.96 ...,  1.96  1.96  1.96]]

# %%
k=1;q=1;d=1;e=0
V=k*q/sqrt(X**2.+(Y-d)**2.) - k*q/sqrt(X**2.+(Y+d)**2.)
U=k*q/sqrt((X-e)**2.+Y**2.) - k*q/sqrt((X+e)**2.+Y**2.)

# %%
from mpl_toolkits.mplot3d import Axes3D
fig=figure()
ax=fig.gca(projections='3d')
p=ax.plot_surface(X,Y,V,rstride=1,cstride=1,linewidth=0,cmap=cm.coolwarm)
#help(Axes3d.plot_surface)
cb=fig.colorbar(p,shrink=.5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-3d6344124cd8> in <module>()
#       1 from mpl_toolkits.mplot3d import Axes3D
#       2 fig=figure()
# ----> 3 ax=fig.gca(projections='3d')
#       4 p=ax.plot_surface(X,Y,V,rstride=1,cstride=1,linewidth=0,cmap=cm.coolwarm)
#       5 #help(Axes3d.plot_surface)
#
# C:\Python27\lib\site-packages\matplotlib\figure.pyc in gca(self, **kwargs)
#    1051             if isinstance(ax, projection_class):
#    1052                 return ax
# -> 1053         return self.add_subplot(111, **kwargs)
#    1054
#    1055     def sca(self, a):
#
# C:\Python27\lib\site-packages\matplotlib\figure.pyc in add_subplot(self, *args, **kwargs)
#     775                     # more similar to add_axes.
#     776
# --> 777             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#     778         self._axstack.add(key, a)
#     779         self.sca(a)
#
# C:\Python27\lib\site-packages\matplotlib\axes.pyc in __init__(self, fig, *args, **kwargs)
#    8370
#    8371         # _axes_class is set in the subplot_class_factory
# -> 8372         self._axes_class.__init__(self, fig, self.figbox, **kwargs)
#    8373
#    8374
#
# C:\Python27\lib\site-packages\matplotlib\axes.pyc in __init__(self, fig, rect, axisbg, frameon, sharex, sharey, label, xscale, yscale, **kwargs)
#     481             self.set_yscale(yscale)
#     482
# --> 483         if len(kwargs): martist.setp(self, **kwargs)
#     484
#     485         if self.xaxis is not None:
#
# C:\Python27\lib\site-packages\matplotlib\artist.pyc in setp(obj, *args, **kwargs)
#    1206             s = s.lower()
#    1207             funcName = "set_%s"%s
# -> 1208             func = getattr(o, funcName)
#    1209             ret.extend( [func(val)] )
#    1210     return [x for x in cbook.flatten(ret)]
#
# AttributeError: 'AxesSubplot' object has no attribute 'set_projections'

# %%
#contours
levels=array([8,4,2,1,.5,.25,0,-.25,-.5,-1,-2,-4,-8])

contour(X,Y,V,levels,linewidths=4,cmap=cm.autumn)
# Out:
# <matplotlib.contour.QuadContourSet instance at 0x000000000A3A0348>

# %%
dx=12/51.
dy=12/51.
x=arange(-6,6,dx)
y=arange(-6,6,dy)
X,Y = meshgrid(x,y)
g=e**(-X**2-Y**2)
levels=array([8,4,2,1,.5,.25,-.125,0,.125,-.25,-.5,-1-2,-4,-8])

contour(X,Y,g,levels,linewidths=4,cmap=cm.autumn)
# Out:
# <matplotlib.contour.QuadContourSet instance at 0x000000000AD469C8>

# %%
k=8.98#N*m^2/C^2
q=1e-9#C
d=2
e=2
dx=12/101.
dy=12/101.
x=arange(-6,6,dx)
y=arange(-6,6,dy)
X,Y=meshgrid(x,y)
V=k*q/sqrt(X**2.+(Y-d)**2.) + k*q/sqrt(X**2.+(Y+d)**2.)
U=0-k*q/sqrt((X-e)**2.+Y**2.) - k*q/sqrt((X+e)**2.+Y**2.)
levels=array([-1e-7,-1e-8,-1e-9,-1e-10,0,1e-10,1e-9,1e-8,1e-7])
print U.min()
print V.min()
print U.max()
print V.max()
contour(X,Y,U+V,levels,linewidths=4,cmap=cm.jet)
# Out:
# -1.28042690948e-07
# 2.14330194053e-09
# -2.14330194053e-09
# 1.28042690948e-07
# <matplotlib.contour.QuadContourSet instance at 0x000000000AAF4B88>
