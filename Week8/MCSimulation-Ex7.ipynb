# %%
import numpy.random
#numpy.random?
print numpy.random.random(5)
print numpy.random.random(5)
# Out:
# [ 0.1955413   0.12765003  0.33159233  0.93345277  0.3805185 ]
# [ 0.59802878  0.55812291  0.80570813  0.48682549  0.72781271]

# %%
numpy.random.seed(4242)
print "Using seed = 4242:",
print numpy.random.random(5)
# Out:
# Using seed = 4242: [ 0.32494949  0.94041458  0.91400794  0.28650938  0.78180262]

# %%
numpy.random.seed(None)
print "Using seed = 4242:",
print numpy.random.random(5)
# Out:
# Using seed = 4242: [ 0.91943637  0.84616002  0.32862668  0.70552605  0.07876971]

# %%
numpy.random.seed(4242)
print "Using seed = 4242: We ahould see same numbers as before"
print numpy.random.random(5)
# Out:
# Using seed = 4242: We ahould see same numbers as before
# [ 0.32494949  0.94041458  0.91400794  0.28650938  0.78180262]

# %%
numpy.random.seed(None)
figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
z=numpy.random.random(100000)
hist(z,100,normed=True)
plot([0,1.],[1.,1.],'r-',lw=3)
xlabel("x",fontsize=20)
ylabel("sample probability",fontsize=30)

# %%
x=arange(0.,pi+.001,.01)
f=lambda x: sin(x)/2
F=lambda x: (cos(0)-cos(x))/2
plot(x,f(x),label="True distribution",lw=3)
plot(x,F(x),label="Cumulative distribution",lw=3)
xlim(0,3.5)
ylim(0,1.1)
legend(loc=0)
show()

# %%
N=10000
z=numpy.random.random_sample(N)
Finv = lambda z: arccos(cos(0)-2*z)
xsamples=Finv(z)
hist(xsamples,50,normed=True,label="Sampled Distribution")
plot(x,f(x),label="True distribution",lw=3,color='red')
xlim(0.,pi)
ylim(0.,.7)
legend(loc=0)
show()

# %% [markdown]
# Part 1:
# =========
# Exercise 1:
# ------------
# a)

# %%
lam=1.
f = lambda x: lam*e**(-lam*x)
F = lambda x: 1-e**(-lam*x)
Finv = lambda x: -1*float(log(1-F(x))/lam)

# %% [markdown]
# b)

# %%
figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
N=100000.
dx=1/N
x=arange(0.,5+dx/2,dx)
plot(x,f(x),color='red',lw=3,label="f(x)")
plot(x,F(x),lw=3,label="F(x)")
legend(loc=5)
show()

# %% [markdown]
# c)

# %%
N=10000
dx=1/100.
z=numpy.random.random_sample(N)
x=arange(0.,5+dx/2,dx)
Finv = lambda z: -log(1-z)/lam
xsam=Finv(z)
hist(xsam,50,normed=True,label="Sampled Distribution")
plot(x,f(x),label='True distribution',lw=3)

# %% [markdown]
# Exercise 2:
# -----------
# a)

# %%
lam=1.
xmax=10
N=10000.
dx=xmax/N
x=arange(0,xmax+dx/2,dx)
z=numpy.random.random(N)
f = lambda x: lam*e**(-lam*x)
F = cumsum(f(x))/(cumsum(f(x))[xmax/dx])
g= searchsorted(F,z)
print g
print x[g]
# Out:
# [ 456  250 1243 ..., 1375  979 1448]
# [ 0.456  0.25   1.243 ...,  1.375  0.979  1.448]

# %% [markdown]
# b)

# %%
hist(x[g],50,normed=True,label="Sampled Distribution")
plot(x,f(x),label='True distribution',lw=3)
plot(x,F,label="CDF Transform")
legend()
show()

# %%
def distribute1d(x,prob,N):
    """takes and numberical distribution prob, on the interval defined by the array x, and returns an array of N sampled values that are statistically the same as the input data."""
    z=numpy.random.random(N)
    F = cumsum(prob)/(cumsum(prob)[N])
    g= searchsorted(F,z)
    xsamples=x[g]
    return xsamples
N=10000
print x[g]
print len(x),len(distribute1d(x,f(x),N))
plot(x,f(x),label='x[g]')
hist(distribute1d(x,f(x),N),50,normed=True,label="Distribute1d")
legend()
show()
# Out:
# [ 0.456  0.25   1.243 ...,  1.375  0.979  1.448]
# 10001 10000

# %% [markdown]
# Exercise 3
# --------------
# a)

# %%
d=15e-6
a=10e-6
L=1
lam=632.8e-9
p=10000.
xmin=-.2
xmax=.2
dx=(xmax-xmin)/p
x=arange(xmin,xmax+dx/2,dx)
sinc = lambda x: sin(pi*x)/(pi*x)
Issd = (sinc(a*x/(lam*L)))**2
Idsi = (cos(2*pi*d*x/(lam*L)))**2
Idst=Issd*Idsi

# %% [markdown]
# b)

# %%
h=distribute1d(x,Idst,p)
print shape(Idst), shape(h)
n,bins,patches=hist(h,50,normed=True,label="Sampled data")
plot(x,Idst*max(n),color='red',lw=3,label="True Distribution")
legend()
show()
# Out:
# (10001L,) (10000L,)

# %%
p=1
dx=(xmax-xmin)/10000.
x=arange(xmin,xmax+dx/2,dx)
sinc = lambda x: sin(pi*x)/(pi*x)
Issd = (sinc(a*x/(lam*L)))**2
Idsi = (cos(2*pi*d*x/(lam*L)))**2
Idst=Issd*Idsi
z=numpy.random.random_sample(N)
G=distribute1d(z,f(z),N)
plot(z,G,label="Sampled Distribution")
plot(x,Idst,color='red',lw=3,label="True Distribution")
legend()
show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-64-65ac12bbaf6f> in <module>()
#       7 Idst=Issd*Idsi
#       8 z=numpy.random.random_sample(N)
# ----> 9 G=distribute1d(z,f(z),N)
#      10 plot(z,G,label="Sampled Distribution")
#      11 plot(x,Idst,color='red',lw=3,label="True Distribution")
#
# <ipython-input-61-780ecce30002> in distribute1d(x, prob, N)
#       2     """takes and numberical distribution prob, on the interval defined by the array x, and returns an array of N sampled values that are statistically the same as the input data."""
#       3     z=numpy.random.random(N)
# ----> 4     F = cumsum(prob)/(cumsum(prob)[N])
#       5     g= searchsorted(F,z)
#       6     xsamples=x[g]
#
# IndexError: index out of bounds

# %%
p=10
dx=(xmax-xmin)/p
x=arange(xmin,xmax+dx/2,dx)
sinc = lambda x: sin(pi*x)/(pi*x)
Issd = (sinc(a*x/(lam*L)))**2
Idsi = (cos(2*pi*d*x/(lam*L)))**2
Idst=Issd*Idsi
h=distribute1d(x,Idst,p)
n,bins,patches=hist(h,50,normed=True,label="Sampled data")
plot(x,Idst*max(n),color='red',lw=3,label="True Distribution")
legend()
show()

# %%
p=100
dx=(xmax-xmin)/p
x=arange(xmin,xmax+dx/2,dx)
sinc = lambda x: sin(pi*x)/(pi*x)
Issd = (sinc(a*x/(lam*L)))**2
Idsi = (cos(2*pi*d*x/(lam*L)))**2
Idst=Issd*Idsi
h=distribute1d(x,Idst,p)
n,bins,patches=hist(h,50,normed=True,label="Sampled data")
plot(x,Idst*max(n),color='red',lw=3,label="True Distribution")
legend()
show()

# %%
p=1000
dx=(xmax-xmin)/p
x=arange(xmin,xmax+dx/2,dx)
sinc = lambda x: sin(pi*x)/(pi*x)
Issd = (sinc(a*x/(lam*L)))**2
Idsi = (cos(2*pi*d*x/(lam*L)))**2
Idst=Issd*Idsi
h=distribute1d(x,Idst,p)
n,bins,patches=hist(h,50,normed=True,label="Sampled data")
plot(x,Idst*max(n),color='red',lw=3,label="True Distribution")
legend()
show()

# %%
# As we add more photons, the amplitude of the interference pattern decreases

# %% [markdown]
# Part 2
# ========
# a)

# %%
a=1.5
b=6
f = lambda x: a*(b**(-a))*(x**(a-1))*e**((-x/b)**a)
F=lambda x: -(b**2)*e**((-x/b)**a)
#I call bs on "Mathematica can do any ingetral," I defeated Mathematica.

# %% [markdown]
# b)

# %%
Finv=lambda x: b*(-log(-F(x)/b**2))**(1/a)

# %% [markdown]
# c)

# %%
N=10000
z=abs(numpy.random.random_sample(N))
xsam=Finv(z)

# %% [markdown]
# d)

# %%
plot(x,f(x),label='f(x)')
n,bins,patches=hist(xsam,50,normed=True,label="Sampled data")
#This sould've worked since I copied what was done in class, but this may be due to the functions we're graphing
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-68-dd6060010317> in <module>()
#       1 plot(x,f(x),label='f(x)')
# ----> 2 n,bins,patches=hist(xsam,50,normed=True,label="Sampled data")
#       3 #This sould've worked since I copied what was done in class, but this may be due to the functions we're graphing
#
# C:\Python27\lib\site-packages\matplotlib\pyplot.pyc in hist(x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, hold, **kwargs)
#    2330         ax.hold(hold)
#    2331     try:
# -> 2332         ret = ax.hist(x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, **kwargs)
#    2333         draw_if_interactive()
#    2334     finally:
#
# ...

# %% [markdown]
# Part 3
# ======
# a)

# %%
f=lambda x: (60*x**3)*(1-x)**2

# %%
N=10000.
x=arange(0.,15.,1/N)
xmin=1.7
xmax=12.4
subx=x[logical_and((x>xmin),(x<xmax))]
ymax=max(f(subx))*1.05
ymin=0.
samples_x=xmin+(xmax-xmin)*random_sample(N);
samples_y=ymin+(ymax-ymin)*random_sample(N);

# %% [markdown]
# b) density distribution, the CDF, and a histogram of the sampled distribution on
# the same graph

# %%
figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
F=lambda x: 20*x**3 - 30*x**4 + 12*x**5
z=samples_x
G=distribute1d(x,f(x),N)
n,bins,patches=hist(G,50,normed=True,label="Sampled data")
plot(x,f(x),label='f(x)')
legend()
show()
